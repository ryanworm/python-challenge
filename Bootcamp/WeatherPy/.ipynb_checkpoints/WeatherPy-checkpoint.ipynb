# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from urllib.parse import quote_plus
from pprint import pprint 
import json

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding latitude/longitude (lat_lng) and cities
lat_lngs = []
cities = []


# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 594

# %%
# creating an empty list 
city_data = []

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key + "&q=" + city
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7af1d12a1c4e0e958b9f4a3231142e8e&q=tuatapere

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
for city in cities: 
    try:
        r = requests.get('http://api.openweathermap.org/data/2.5/weather', params={'q': city, 'appid': weather_api_key})
        r_data = r.json()
        #Creating variables for the JSON object   
        c_ID = r_data["id"]
        name = r_data["name"]
        lat= r_data["coord"]['lat']
        lon= r_data["coord"]['lon']
        maxtemp = r_data["main"]['temp_max']
        humidity = r_data["main"]["humidity"]
        clouds = r_data["clouds"]['all']
        windSpeed = r_data["wind"]['speed']
        country = r_data["sys"]["country"]
        date = r_data['dt']
        pprint(f'Evaluating city number: {c_ID}, {r_data["name"]}')
#creating a list of dictionaries to build the dataframe         
        city_data.append({
                "City" : name,
                "Lat" : lat,    
                "Lng" : lon,
                "Max Temp" : maxtemp,
                "Humidity" : humidity,
                "Cloudiness" : clouds,
                "Wind Speed" : windSpeed,
                "Country" : country,      
                "CityDate" : date
       })
        pprint(f'Appending {name} to "city_data"')
    except KeyError:
        pass
# Out:
# 'Evaluating city number: 3421982, Maniitsoq'
# 'Appending Maniitsoq to "city_data"'
# 'Evaluating city number: 2206939, Bluff'
# 'Appending Bluff to "city_data"'
# 'Evaluating city number: 3671387, Puerto Nariño'
# 'Appending Puerto Nariño to "city_data"'
# 'Evaluating city number: 2446796, Bilma'
# 'Appending Bilma to "city_data"'
# 'Evaluating city number: 5870133, Nome'
# 'Appending Nome to "city_data"'
# 'Evaluating city number: 1490085, Tarko-Sale'
# 'Appending Tarko-Sale to "city_data"'
# 'Evaluating city number: 257122, Methóni'
# 'Appending Methóni to "city_data"'
# 'Evaluating city number: 935215, Saint-Philippe'
# 'Appending Saint-Philippe to "city_data"'
# 'Evaluating city number: 3461370, Imbituba'
# 'Appending Imbituba to "city_data"'
# 'Evaluating city number: 795243, Snezhnogorsk'
# 'Appending Snezhnogorsk to "city_data"'
# 'Evaluating city number: 3833367, Ushuaia'
# 'Appending Ushuaia to "city_data"'
# 'Evaluating city number: 3870243, Taltal'
# 'Appending Taltal to "city_data"'
# 'Evaluating city number: 5545269, Price'
# 'Appending Price to "city_data"'
# 'Evaluating city number: 2075265, Busselton'
# 'Appending Busselton to "city_data"'
# 'Evaluating city number: 5106841, Albany'
# 'Appending Albany to "city_data"'
# 'Evaluating city number: 4034551, Faanui'
# 'Appending Faanui to "city_data"'
# 'Evaluating city number: 964432, Port Alfred'
# 'Appending Port Alfred to "city_data"'
# 'Evaluating city number: 1279945, Jiuquan'
# 'Appending Jiuquan to "city_data"'
# 'Evaluating city number: 934649, Cap Malheureux'
# 'Appending Cap Malheureux to "city_data"'
# 'Evaluating city number: 4030556, Rikitea'
# 'Appending Rikitea to "city_data"'
# 'Evaluating city number: 3369157, Cape Town'
# 'Appending Cape Town to "city_data"'
# 'Evaluating city number: 5866583, Saint Paul Harbor'
# 'Appending Saint Paul Harbor to "city_data"'
# 'Evaluating city number: 5122534, Jamestown'
# 'Appending Jamestown to "city_data"'
# 'Evaluating city number: 2126123, Chokurdakh'
# 'Appending Chokurdakh to "city_data"'
# 'Evaluating city number: 1507390, Dikson'
# 'Appending Dikson to "city_data"'
# 'Evaluating city number: 2152659, Port Macquarie'
# 'Appending Port Macquarie to "city_data"'
# 'Evaluating city number: 5880054, Barrow'
# 'Appending Barrow to "city_data"'
# 'Evaluating city number: 2126710, Beringovskiy'
# 'Appending Beringovskiy to "city_data"'
# 'Evaluating city number: 3366880, Hermanus'
# 'Appending Hermanus to "city_data"'
# 'Evaluating city number: 3855065, General Roca'
# 'Appending General Roca to "city_data"'
# 'Evaluating city number: 2110227, Butaritari'
# 'Appending Butaritari to "city_data"'
# 'Evaluating city number: 986717, Kruisfontein'
# 'Appending Kruisfontein to "city_data"'
# 'Evaluating city number: 3448903, São João da Barra'
# 'Appending São João da Barra to "city_data"'
# 'Evaluating city number: 4020109, Atuona'
# 'Appending Atuona to "city_data"'
# 'Evaluating city number: 2109528, Buala'
# 'Appending Buala to "city_data"'
# 'Evaluating city number: 700569, Mykolayiv'
# 'Appending Mykolayiv to "city_data"'
# 'Evaluating city number: 3628267, San Joaquin'
# 'Appending San Joaquin to "city_data"'
# 'Evaluating city number: 5847411, Kahului'
# 'Appending Kahului to "city_data"'
# 'Evaluating city number: 3398931, Gilbués'
# 'Appending Gilbués to "city_data"'
# 'Evaluating city number: 1276328, Bhadrāchalam'
# 'Appending Bhadrāchalam to "city_data"'
# 'Evaluating city number: 3424607, Tasiilaq'
# 'Appending Tasiilaq to "city_data"'
# 'Evaluating city number: 1927639, Yueyang'
# 'Appending Yueyang to "city_data"'
# 'Evaluating city number: 546105, Nikolskoye'
# 'Appending Nikolskoye to "city_data"'
# 'Evaluating city number: 4031637, Lavrentiya'
# 'Appending Lavrentiya to "city_data"'
# 'Evaluating city number: 511416, Perelyub'
# 'Appending Perelyub to "city_data"'
# 'Evaluating city number: 2122090, Pevek'
# 'Appending Pevek to "city_data"'
# 'Evaluating city number: 3471451, Arraial do Cabo'
# 'Appending Arraial do Cabo to "city_data"'
# 'Evaluating city number: 5882953, Aklavik'
# 'Appending Aklavik to "city_data"'
# 'Evaluating city number: 4035715, Avarua'
# 'Appending Avarua to "city_data"'
# 'Evaluating city number: 6185377, Yellowknife'
# 'Appending Yellowknife to "city_data"'
# 'Evaluating city number: 3374083, Bathsheba'
# 'Appending Bathsheba to "city_data"'
# 'Evaluating city number: 1282256, Hithadhoo'
# 'Appending Hithadhoo to "city_data"'
# 'Evaluating city number: 2126199, Cherskiy'
# 'Appending Cherskiy to "city_data"'
# 'Evaluating city number: 1631393, Prabumulih'
# 'Appending Prabumulih to "city_data"'
# 'Evaluating city number: 3466704, Castro'
# 'Appending Castro to "city_data"'
# 'Evaluating city number: 6255012, Flinders'
# 'Appending Flinders to "city_data"'
# 'Evaluating city number: 2032614, Baruun-Urt'
# 'Appending Baruun-Urt to "city_data"'
# 'Evaluating city number: 4032243, Vaini'
# 'Appending Vaini to "city_data"'
# 'Evaluating city number: 1501377, Kungurtug'
# 'Appending Kungurtug to "city_data"'
# 'Evaluating city number: 6186122, Wiarton'
# 'Appending Wiarton to "city_data"'
# 'Evaluating city number: 2270385, Camacha'
# 'Appending Camacha to "city_data"'
# 'Evaluating city number: 5924351, Clyde River'
# 'Appending Clyde River to "city_data"'
# 'Evaluating city number: 4231997, Avera'
# 'Appending Avera to "city_data"'
# 'Evaluating city number: 5746545, Portland'
# 'Appending Portland to "city_data"'
# 'Evaluating city number: 2013216, Vysokogornyy'
# 'Appending Vysokogornyy to "city_data"'
# 'Evaluating city number: 1052373, Beira'
# 'Appending Beira to "city_data"'
# 'Evaluating city number: 3874787, Punta Arenas'
# 'Appending Punta Arenas to "city_data"'
# 'Evaluating city number: 2630299, Hofn'
# 'Appending Hofn to "city_data"'
# 'Evaluating city number: 3418910, Upernavik'
# 'Appending Upernavik to "city_data"'
# 'Evaluating city number: 1623197, Tual'
# 'Appending Tual to "city_data"'
# 'Evaluating city number: 1259385, Port Blair'
# 'Appending Port Blair to "city_data"'
# 'Evaluating city number: 2194098, Ahipara'
# 'Appending Ahipara to "city_data"'
# 'Evaluating city number: 2155415, New Norfolk'
# 'Appending New Norfolk to "city_data"'
# 'Evaluating city number: 6165406, Thompson'
# 'Appending Thompson to "city_data"'
# 'Evaluating city number: 2208248, Kaitangata'
# 'Appending Kaitangata to "city_data"'
# 'Evaluating city number: 1498161, Muzhi'
# 'Appending Muzhi to "city_data"'
# 'Evaluating city number: 3985168, San Patricio'
# 'Appending San Patricio to "city_data"'
# 'Evaluating city number: 3792389, Isnos'
# 'Appending Isnos to "city_data"'
# 'Evaluating city number: 1174167, Khanpur'
# 'Appending Khanpur to "city_data"'
# 'Evaluating city number: 3831208, Qaanaaq'
# 'Appending Qaanaaq to "city_data"'
# 'Evaluating city number: 2071860, Esperance'
# 'Appending Esperance to "city_data"'
# 'Evaluating city number: 933995, Souillac'
# 'Appending Souillac to "city_data"'
# 'Evaluating city number: 1687186, Sarangani'
# 'Appending Sarangani to "city_data"'
# 'Evaluating city number: 2063056, Port Augusta'
# 'Appending Port Augusta to "city_data"'
# 'Evaluating city number: 6201424, Mataura'
# 'Appending Mataura to "city_data"'
# 'Evaluating city number: 2090021, Namatanai'
# 'Appending Namatanai to "city_data"'
# 'Evaluating city number: 1586350, Cam Ranh'
# 'Appending Cam Ranh to "city_data"'
# 'Evaluating city number: 4984016, Allen Park'
# 'Appending Allen Park to "city_data"'
# 'Evaluating city number: 3446295, Torres'
# 'Appending Torres to "city_data"'
# 'Evaluating city number: 2187393, Manutuke'
# 'Appending Manutuke to "city_data"'
# 'Evaluating city number: 6167817, Torbay'
# 'Appending Torbay to "city_data"'
# 'Evaluating city number: 2242885, Camabatela'
# 'Appending Camabatela to "city_data"'
# 'Evaluating city number: 3576994, Cockburn Town'
# 'Appending Cockburn Town to "city_data"'
# 'Evaluating city number: 1263528, Marhaura'
# 'Appending Marhaura to "city_data"'
# 'Evaluating city number: 3466980, Caravelas'
# 'Appending Caravelas to "city_data"'
# 'Evaluating city number: 239899, Bria'
# 'Appending Bria to "city_data"'
# 'Evaluating city number: 2033413, Cuiluan'
# 'Appending Cuiluan to "city_data"'
# 'Evaluating city number: 2022572, Khatanga'
# 'Appending Khatanga to "city_data"'
# 'Evaluating city number: 1258207, Renukoot'
# 'Appending Renukoot to "city_data"'
# 'Evaluating city number: 3929611, San Jerónimo'
# 'Appending San Jerónimo to "city_data"'
# 'Evaluating city number: 1819729, Hong Kong'
# 'Appending Hong Kong to "city_data"'
# 'Evaluating city number: 2514651, Los Llanos de Aridane'
# 'Appending Los Llanos de Aridane to "city_data"'
# 'Evaluating city number: 3527065, Hopelchén'
# 'Appending Hopelchén to "city_data"'
# 'Evaluating city number: 1048364, Chokwé'
# 'Appending Chokwé to "city_data"'
# 'Evaluating city number: 2084442, Vanimo'
# 'Appending Vanimo to "city_data"'
# 'Evaluating city number: 1006984, East London'
# 'Appending East London to "city_data"'
# 'Evaluating city number: 2092740, Lae'
# 'Appending Lae to "city_data"'
# 'Evaluating city number: 3652764, Puerto Ayora'
# 'Appending Puerto Ayora to "city_data"'
# 'Evaluating city number: 4031742, Egvekinot'
# 'Appending Egvekinot to "city_data"'
# 'Evaluating city number: 3860259, Córdoba'
# 'Appending Córdoba to "city_data"'
# 'Evaluating city number: 964420, Port Elizabeth'
# 'Appending Port Elizabeth to "city_data"'
# 'Evaluating city number: 2439376, Tahoua'
# 'Appending Tahoua to "city_data"'
# 'Evaluating city number: 1651810, Airai'
# 'Appending Airai to "city_data"'
# 'Evaluating city number: 2163355, Hobart'
# 'Appending Hobart to "city_data"'
# 'Evaluating city number: 5855927, Hilo'
# 'Appending Hilo to "city_data"'
# 'Evaluating city number: 570086, Chagoda'
# 'Appending Chagoda to "city_data"'
# 'Evaluating city number: 934322, Mahébourg'
# 'Appending Mahébourg to "city_data"'
# 'Evaluating city number: 3455908, Oliveira'
# 'Appending Oliveira to "city_data"'
# 'Evaluating city number: 3985710, Cabo San Lucas'
# 'Appending Cabo San Lucas to "city_data"'
# 'Evaluating city number: 1633419, Padang'
# 'Appending Padang to "city_data"'
# 'Evaluating city number: 5848280, Kapaa'
# 'Appending Kapaa to "city_data"'
# 'Evaluating city number: 1802238, Loudi'
# 'Appending Loudi to "city_data"'
# 'Evaluating city number: 739636, Şile'
# 'Appending Şile to "city_data"'
# 'Evaluating city number: 4235229, Carlyle'
# 'Appending Carlyle to "city_data"'
# 'Evaluating city number: 3421193, Paamiut'
# 'Appending Paamiut to "city_data"'
# 'Evaluating city number: 2126785, Belaya Gora'
# 'Appending Belaya Gora to "city_data"'
# 'Evaluating city number: 543246, Kozhva'
# 'Appending Kozhva to "city_data"'
# 'Evaluating city number: 3439525, Young'
# 'Appending Young to "city_data"'
# 'Evaluating city number: 2120591, Tilichiki'
# 'Appending Tilichiki to "city_data"'
# 'Evaluating city number: 2123814, Leningradskiy'
# 'Appending Leningradskiy to "city_data"'
# 'Evaluating city number: 1014653, Burgersdorp'
# 'Appending Burgersdorp to "city_data"'
# 'Evaluating city number: 3391412, Portel'
# 'Appending Portel to "city_data"'
# 'Evaluating city number: 3430863, Mar del Plata'
# 'Appending Mar del Plata to "city_data"'
# 'Evaluating city number: 3899695, Ancud'
# 'Appending Ancud to "city_data"'
# 'Evaluating city number: 211647, Lodja'
# 'Appending Lodja to "city_data"'
# 'Evaluating city number: 6170031, Tuktoyaktuk'
# 'Appending Tuktoyaktuk to "city_data"'
# 'Evaluating city number: 5864145, Homer'
# 'Appending Homer to "city_data"'
# 'Evaluating city number: 5861897, Fairbanks'
# 'Appending Fairbanks to "city_data"'
# 'Evaluating city number: 3984997, San Quintín'
# 'Appending San Quintín to "city_data"'
# 'Evaluating city number: 3163146, Andenes'
# 'Appending Andenes to "city_data"'
# 'Evaluating city number: 3382160, Cayenne'
# 'Appending Cayenne to "city_data"'
# 'Evaluating city number: 1645528, Denpasar'
# 'Appending Denpasar to "city_data"'
# 'Evaluating city number: 6620339, Karratha'
# 'Appending Karratha to "city_data"'
# 'Evaluating city number: 2093846, Kiunga'
# 'Appending Kiunga to "city_data"'
# 'Evaluating city number: 478297, Usogorsk'
# 'Appending Usogorsk to "city_data"'
# 'Evaluating city number: 3430545, Morón'
# 'Appending Morón to "city_data"'
# 'Evaluating city number: 4031574, Provideniya'
# 'Appending Provideniya to "city_data"'
# 'Evaluating city number: 5903535, Blairmore'
# 'Appending Blairmore to "city_data"'
# 'Evaluating city number: 3372760, Praia da Vitória'
# 'Appending Praia da Vitória to "city_data"'
# 'Evaluating city number: 1649150, Bengkulu'
# 'Appending Bengkulu to "city_data"'
# 'Evaluating city number: 1785974, Yuci'
# 'Appending Yuci to "city_data"'
# 'Evaluating city number: 3394023, Natal'
# 'Appending Natal to "city_data"'
# 'Evaluating city number: 1812256, Dongsheng'
# 'Appending Dongsheng to "city_data"'
# 'Evaluating city number: 5367788, Lompoc'
# 'Appending Lompoc to "city_data"'
# 'Evaluating city number: 7117100, Vila'
# 'Appending Vila to "city_data"'
# 'Evaluating city number: 2155562, Nelson Bay'
# 'Appending Nelson Bay to "city_data"'
# 'Evaluating city number: 4409896, Springfield'
# 'Appending Springfield to "city_data"'
# 'Evaluating city number: 286245, Sur'
# 'Appending Sur to "city_data"'
# 'Evaluating city number: 493201, Shuyskoye'
# 'Appending Shuyskoye to "city_data"'
# 'Evaluating city number: 5546220, Saint George'
# 'Appending Saint George to "city_data"'
# 'Evaluating city number: 1735106, George Town'
# 'Appending George Town to "city_data"'
# 'Evaluating city number: 3358666, Aranos'
# 'Appending Aranos to "city_data"'
# 'Evaluating city number: 2074865, Carnarvon'
# 'Appending Carnarvon to "city_data"'
# 'Evaluating city number: 4026082, Lázaro Cárdenas'
# 'Appending Lázaro Cárdenas to "city_data"'
# 'Evaluating city number: 3380290, Sinnamary'
# 'Appending Sinnamary to "city_data"'
# 'Evaluating city number: 2112802, Hasaki'
# 'Appending Hasaki to "city_data"'
# 'Evaluating city number: 1688696, San Policarpo'
# 'Appending San Policarpo to "city_data"'
# 'Evaluating city number: 3516171, Barra de Tecoanapa'
# 'Appending Barra de Tecoanapa to "city_data"'
# 'Evaluating city number: 2033196, Zhangjiakou'
# 'Appending Zhangjiakou to "city_data"'
# 'Evaluating city number: 3443061, Chui'
# 'Appending Chui to "city_data"'
# 'Evaluating city number: 1863997, Fukuechō'
# 'Appending Fukuechō to "city_data"'
# 'Evaluating city number: 1488903, Turukhansk'
# 'Appending Turukhansk to "city_data"'
# 'Evaluating city number: 3883457, Lebu'
# 'Appending Lebu to "city_data"'
# 'Evaluating city number: 6089245, Norman Wells'
# 'Appending Norman Wells to "city_data"'
# 'Evaluating city number: 286621, Salalah'
# 'Appending Salalah to "city_data"'
# 'Evaluating city number: 343300, Asmara'
# 'Appending Asmara to "city_data"'
# 'Evaluating city number: 1622318, Waingapu'
# 'Appending Waingapu to "city_data"'
# 'Evaluating city number: 5282297, Bethel'
# 'Appending Bethel to "city_data"'
# 'Evaluating city number: 2063036, Port Lincoln'
# 'Appending Port Lincoln to "city_data"'
# 'Evaluating city number: 1486321, Yar-Sale'
# 'Appending Yar-Sale to "city_data"'
# 'Evaluating city number: 219414, Basoko'
# 'Appending Basoko to "city_data"'
# 'Evaluating city number: 3174050, Province of Mantua'
# 'Appending Province of Mantua to "city_data"'
# 'Evaluating city number: 4954611, Watertown'
# 'Appending Watertown to "city_data"'
# 'Evaluating city number: 1244926, Hambantota'
# 'Appending Hambantota to "city_data"'
# 'Evaluating city number: 2022304, Khorinsk'
# 'Appending Khorinsk to "city_data"'
# 'Evaluating city number: 1492566, Severo-Yeniseyskiy'
# 'Appending Severo-Yeniseyskiy to "city_data"'
# 'Evaluating city number: 2353099, Abakaliki'
# 'Appending Abakaliki to "city_data"'
# 'Evaluating city number: 4684904, Dallas'
# 'Appending Dallas to "city_data"'
# 'Evaluating city number: 3428068, San Vicente'
# 'Appending San Vicente to "city_data"'
# 'Evaluating city number: 1106643, Quatre Cocos'
# 'Appending Quatre Cocos to "city_data"'
# 'Evaluating city number: 1269979, Homnābād'
# 'Appending Homnābād to "city_data"'
# 'Evaluating city number: 6690296, Saint-Joseph'
# 'Appending Saint-Joseph to "city_data"'
# 'Evaluating city number: 2189343, Kaeo'
# 'Appending Kaeo to "city_data"'
# 'Evaluating city number: 548114, Kislovodsk'
# 'Appending Kislovodsk to "city_data"'
# 'Evaluating city number: 605155, Kiruna'
# 'Appending Kiruna to "city_data"'
# 'Evaluating city number: 2729907, Longyearbyen'
# 'Appending Longyearbyen to "city_data"'
# 'Evaluating city number: 1015776, Bredasdorp'
# 'Appending Bredasdorp to "city_data"'
# 'Evaluating city number: 2180815, Tuatapere'
# 'Appending Tuatapere to "city_data"'
# 'Evaluating city number: 2012956, Yerbogachën'
# 'Appending Yerbogachën to "city_data"'
# 'Evaluating city number: 364103, Wad Medani'
# 'Appending Wad Medani to "city_data"'
# 'Evaluating city number: 3013748, Hauterive'
# 'Appending Hauterive to "city_data"'
# 'Evaluating city number: 4676740, Brownsville'
# 'Appending Brownsville to "city_data"'
# 'Evaluating city number: 3104324, Zaragoza'
# 'Appending Zaragoza to "city_data"'
# 'Evaluating city number: 103630, Najrān'
# 'Appending Najrān to "city_data"'
# 'Evaluating city number: 5969025, Haines Junction'
# 'Appending Haines Junction to "city_data"'
# 'Evaluating city number: 1513087, Nurota'
# 'Appending Nurota to "city_data"'
# 'Evaluating city number: 161616, Balkanabat'
# 'Appending Balkanabat to "city_data"'
# 'Evaluating city number: 2992770, Arrondissement de Mont-de-Marsan'
# 'Appending Arrondissement de Mont-de-Marsan to "city_data"'
# 'Evaluating city number: 1529569, Changji'
# 'Appending Changji to "city_data"'
# 'Evaluating city number: 4794814, Wyndham'
# 'Appending Wyndham to "city_data"'
# 'Evaluating city number: 3397967, Itaituba'
# 'Appending Itaituba to "city_data"'
# 'Evaluating city number: 3445026, Vila Velha'
# 'Appending Vila Velha to "city_data"'
# 'Evaluating city number: 3423146, Ilulissat'
# 'Appending Ilulissat to "city_data"'
# 'Evaluating city number: 2127202, Anadyr'
# 'Appending Anadyr to "city_data"'
# 'Evaluating city number: 2025630, Chara'
# 'Appending Chara to "city_data"'
# 'Evaluating city number: 4036284, Alofi'
# 'Appending Alofi to "city_data"'
# 'Evaluating city number: 5110365, Broome'
# 'Appending Broome to "city_data"'
# 'Evaluating city number: 1502879, Kolosovka'
# 'Appending Kolosovka to "city_data"'
# 'Evaluating city number: 359792, Aswān'
# 'Appending Aswān to "city_data"'
# 'Evaluating city number: 1215350, Bireun'
# 'Appending Bireun to "city_data"'
# 'Evaluating city number: 1650064, Barabai'
# 'Appending Barabai to "city_data"'
# 'Evaluating city number: 119374, Qeshm'
# 'Appending Qeshm to "city_data"'
# 'Evaluating city number: 3372707, Ribeira Grande'
# 'Appending Ribeira Grande to "city_data"'
# 'Evaluating city number: 6355222, Yulara'
# 'Appending Yulara to "city_data"'
# 'Evaluating city number: 110690, Faya'
# 'Appending Faya to "city_data"'
# 'Evaluating city number: 3374210, São Filipe'
# 'Appending São Filipe to "city_data"'
# 'Evaluating city number: 1801180, Maoming'
# 'Appending Maoming to "city_data"'
# 'Evaluating city number: 2070998, Geraldton'
# 'Appending Geraldton to "city_data"'
# 'Evaluating city number: 145724, Lucapa'
# 'Appending Lucapa to "city_data"'
# 'Evaluating city number: 1797438, Zhuangyuan'
# 'Appending Zhuangyuan to "city_data"'
# 'Evaluating city number: 3420846, Qaqortoq'
# 'Appending Qaqortoq to "city_data"'
# 'Evaluating city number: 6137462, Saint-Augustin'
# 'Appending Saint-Augustin to "city_data"'
# 'Evaluating city number: 3372472, Vila Franca do Campo'
# 'Appending Vila Franca do Campo to "city_data"'
# 'Evaluating city number: 2610343, Vestmanna'
# 'Appending Vestmanna to "city_data"'
# 'Evaluating city number: 1106677, Bambous Virieux'
# 'Appending Bambous Virieux to "city_data"'
# 'Evaluating city number: 2035836, Manzhouli'
# 'Appending Manzhouli to "city_data"'
# 'Evaluating city number: 3388847, São Félix do Xingu'
# 'Appending São Félix do Xingu to "city_data"'
# 'Evaluating city number: 915471, Kalabo'
# 'Appending Kalabo to "city_data"'
# 'Evaluating city number: 893485, Chiredzi'
# 'Appending Chiredzi to "city_data"'
# 'Evaluating city number: 2621471, Gilleleje'
# 'Appending Gilleleje to "city_data"'
# 'Evaluating city number: 1636022, Martapura'
# 'Appending Martapura to "city_data"'
# 'Evaluating city number: 2240449, Luanda'
# 'Appending Luanda to "city_data"'
# 'Evaluating city number: 5915327, Cap-aux-Meules'
# 'Appending Cap-aux-Meules to "city_data"'
# 'Evaluating city number: 3386213, Touros'
# 'Appending Touros to "city_data"'
# 'Evaluating city number: 3662342, São Gabriel da Cachoeira'
# 'Appending São Gabriel da Cachoeira to "city_data"'
# 'Evaluating city number: 3453158, Pontalina'
# 'Appending Pontalina to "city_data"'
# 'Evaluating city number: 265040, Andros'
# 'Appending Andros to "city_data"'
# 'Evaluating city number: 4513583, Hamilton'
# 'Appending Hamilton to "city_data"'
# 'Evaluating city number: 1736376, Kota Bharu'
# 'Appending Kota Bharu to "city_data"'
# 'Evaluating city number: 6067472, Marystown'
# 'Appending Marystown to "city_data"'
# 'Evaluating city number: 2020824, Lermontovka'
# 'Appending Lermontovka to "city_data"'
# 'Evaluating city number: 933416, Manyana'
# 'Appending Manyana to "city_data"'
# 'Evaluating city number: 3421719, Narsaq'
# 'Appending Narsaq to "city_data"'
# 'Evaluating city number: 546845, Kochevo'
# 'Appending Kochevo to "city_data"'
# 'Evaluating city number: 5557293, Sitka'
# 'Appending Sitka to "city_data"'
# 'Evaluating city number: 3406545, Balsas'
# 'Appending Balsas to "city_data"'
# 'Evaluating city number: 3144113, Sokna'
# 'Appending Sokna to "city_data"'
# 'Evaluating city number: 2063039, Port Keats'
# 'Appending Port Keats to "city_data"'
# 'Evaluating city number: 4845585, Westport'
# 'Appending Westport to "city_data"'
# 'Evaluating city number: 5851349, Nānākuli'
# 'Appending Nānākuli to "city_data"'
# 'Evaluating city number: 2208425, Zuwārah'
# 'Appending Zuwārah to "city_data"'
# 'Evaluating city number: 6050066, La Ronge'
# 'Appending La Ronge to "city_data"'
# 'Evaluating city number: 2640351, Peterhead'
# 'Appending Peterhead to "city_data"'
# 'Evaluating city number: 1078553, Ampanihy'
# 'Appending Ampanihy to "city_data"'
# 'Evaluating city number: 3533462, Acapulco de Juárez'
# 'Appending Acapulco de Juárez to "city_data"'
# 'Evaluating city number: 1067565, Beloha'
# 'Appending Beloha to "city_data"'
# 'Evaluating city number: 3932145, Pisco'
# 'Appending Pisco to "city_data"'
# 'Evaluating city number: 2409215, Mattru'
# 'Appending Mattru to "city_data"'
# 'Evaluating city number: 55671, Kismayo'
# 'Appending Kismayo to "city_data"'
# 'Evaluating city number: 1688781, City of San Pedro'
# 'Appending City of San Pedro to "city_data"'
# 'Evaluating city number: 1640902, Kawalu'
# 'Appending Kawalu to "city_data"'
# 'Evaluating city number: 2618795, Klaksvík'
# 'Appending Klaksvík to "city_data"'
# 'Evaluating city number: 3393471, Oriximiná'
# 'Appending Oriximiná to "city_data"'
# 'Evaluating city number: 1540711, Muravlenko'
# 'Appending Muravlenko to "city_data"'
# 'Evaluating city number: 64814, Bandarbeyla'
# 'Appending Bandarbeyla to "city_data"'
# 'Evaluating city number: 1283285, Jumla'
# 'Appending Jumla to "city_data"'
# 'Evaluating city number: 6111862, Port Hardy'
# 'Appending Port Hardy to "city_data"'
# 'Evaluating city number: 2264557, Ponta do Sol'
# 'Appending Ponta do Sol to "city_data"'
# 'Evaluating city number: 2128558, Otofuke'
# 'Appending Otofuke to "city_data"'
# 'Evaluating city number: 5866063, Kenai'
# 'Appending Kenai to "city_data"'
# 'Evaluating city number: 5322053, Yuma'
# 'Appending Yuma to "city_data"'
# 'Evaluating city number: 496358, Severnyy'
# 'Appending Severnyy to "city_data"'
# 'Evaluating city number: 3517970, Pochutla'
# 'Appending Pochutla to "city_data"'
# 'Evaluating city number: 777019, Vardø'
# 'Appending Vardø to "city_data"'
# 'Evaluating city number: 3611699, El Guayabito'
# 'Appending El Guayabito to "city_data"'
# 'Evaluating city number: 1277599, Nilagiri'
# 'Appending Nilagiri to "city_data"'
# 'Evaluating city number: 2092164, Lorengau'
# 'Appending Lorengau to "city_data"'
# 'Evaluating city number: 1849563, Tsuruoka'
# 'Appending Tsuruoka to "city_data"'
# 'Evaluating city number: 1272140, Dwārka'
# 'Appending Dwārka to "city_data"'
# 'Evaluating city number: 1142226, Dawlatabad'
# 'Appending Dawlatabad to "city_data"'
# 'Evaluating city number: 1045114, Inhambane'
# 'Appending Inhambane to "city_data"'
# 'Evaluating city number: 3939168, Huarmey'
# 'Appending Huarmey to "city_data"'
# 'Evaluating city number: 1726449, Basco'
# 'Appending Basco to "city_data"'
# 'Evaluating city number: 2094342, Kavieng'
# 'Appending Kavieng to "city_data"'
# 'Evaluating city number: 601551, Akdepe'
# 'Appending Akdepe to "city_data"'
# 'Evaluating city number: 1502105, Krasnogorskoye'
# 'Appending Krasnogorskoye to "city_data"'
# 'Evaluating city number: 3868633, Vallenar'
# 'Appending Vallenar to "city_data"'
# 'Evaluating city number: 5955902, Fort Nelson'
# 'Appending Fort Nelson to "city_data"'
# 'Evaluating city number: 1262216, Nāgaur'
# 'Appending Nāgaur to "city_data"'
# 'Evaluating city number: 478769, Urdoma'
# 'Appending Urdoma to "city_data"'
# 'Evaluating city number: 3453060, Pontes e Lacerda'
# 'Appending Pontes e Lacerda to "city_data"'
# 'Evaluating city number: 2512186, Puerto del Rosario'
# 'Appending Puerto del Rosario to "city_data"'
# 'Evaluating city number: 2137773, Vao'
# 'Appending Vao to "city_data"'
# 'Evaluating city number: 3573899, Point Fortin'
# 'Appending Point Fortin to "city_data"'
# 'Evaluating city number: 3833859, Tres Arroyos'
# 'Appending Tres Arroyos to "city_data"'
# 'Evaluating city number: 5699404, Scottsbluff'
# 'Appending Scottsbluff to "city_data"'
# 'Evaluating city number: 2173911, Broken Hill'
# 'Appending Broken Hill to "city_data"'
# 'Evaluating city number: 358048, Damietta'
# 'Appending Damietta to "city_data"'
# 'Evaluating city number: 2109701, Auki'
# 'Appending Auki to "city_data"'
# 'Evaluating city number: 1529484, Kumul'
# 'Appending Kumul to "city_data"'
# 'Evaluating city number: 3357247, Gobabis'
# 'Appending Gobabis to "city_data"'
# 'Evaluating city number: 1505991, Igarka'
# 'Appending Igarka to "city_data"'
# 'Evaluating city number: 1068971, Antsohihy'
# 'Appending Antsohihy to "city_data"'
# 'Evaluating city number: 2353688, Yako'
# 'Appending Yako to "city_data"'
# 'Evaluating city number: 2028164, Deputatsky'
# 'Appending Deputatsky to "city_data"'
# 'Evaluating city number: 5563839, Fortuna'
# 'Appending Fortuna to "city_data"'
# 'Evaluating city number: 53654, Mogadishu'
# 'Appending Mogadishu to "city_data"'
# 'Evaluating city number: 2456917, Goundam'
# 'Appending Goundam to "city_data"'
# 'Evaluating city number: 6111696, Port-Cartier'
# 'Appending Port-Cartier to "city_data"'
# 'Evaluating city number: 7647007, Bariloche'
# 'Appending Bariloche to "city_data"'
# 'Evaluating city number: 610298, Beyneu'
# 'Appending Beyneu to "city_data"'
# 'Evaluating city number: 2659776, Malters'
# 'Appending Malters to "city_data"'
# 'Evaluating city number: 3402648, Carutapera'
# 'Appending Carutapera to "city_data"'
# 'Evaluating city number: 2015306, Tiksi'
# 'Appending Tiksi to "city_data"'
# 'Evaluating city number: 3936456, Lima'
# 'Appending Lima to "city_data"'
# 'Evaluating city number: 364933, Umm Kaddadah'
# 'Appending Umm Kaddadah to "city_data"'
# 'Evaluating city number: 3391889, Pitimbu'
# 'Appending Pitimbu to "city_data"'
# 'Evaluating city number: 3617697, Mateare'
# 'Appending Mateare to "city_data"'
# 'Evaluating city number: 3466165, Cidreira'
# 'Appending Cidreira to "city_data"'
# 'Evaluating city number: 5859699, College'
# 'Appending College to "city_data"'
# 'Evaluating city number: 4021858, Guerrero Negro'
# 'Appending Guerrero Negro to "city_data"'
# 'Evaluating city number: 2253354, Dakar'
# 'Appending Dakar to "city_data"'
# 'Evaluating city number: 4169452, Punta Gorda'
# 'Appending Punta Gorda to "city_data"'
# 'Evaluating city number: 1701054, Marawi'
# 'Appending Marawi to "city_data"'
# 'Evaluating city number: 3170346, Pombia'
# 'Appending Pombia to "city_data"'
# 'Evaluating city number: 1735902, Sibu'
# 'Appending Sibu to "city_data"'
# 'Evaluating city number: 481964, Tosno'
# 'Appending Tosno to "city_data"'
# 'Evaluating city number: 1499053, Megion'
# 'Appending Megion to "city_data"'
# 'Evaluating city number: 4944903, Nantucket'
# 'Appending Nantucket to "city_data"'
# 'Evaluating city number: 6100799, Pemberton'
# 'Appending Pemberton to "city_data"'
# 'Evaluating city number: 2401495, Booué'
# 'Appending Booué to "city_data"'
# 'Evaluating city number: 1636806, Majene'
# 'Appending Majene to "city_data"'
# 'Evaluating city number: 3356832, Henties Bay'
# 'Appending Henties Bay to "city_data"'
# 'Evaluating city number: 780687, Berlevåg'
# 'Appending Berlevåg to "city_data"'
# 'Evaluating city number: 2012593, Zeya'
# 'Appending Zeya to "city_data"'
# 'Evaluating city number: 2712414, Gävle'
# 'Appending Gävle to "city_data"'
# 'Evaluating city number: 342559, Bedēsa'
# 'Appending Bedēsa to "city_data"'
# 'Evaluating city number: 2112309, Katsuura'
# 'Appending Katsuura to "city_data"'
# 'Evaluating city number: 2122262, Palana'
# 'Appending Palana to "city_data"'
# 'Evaluating city number: 2171099, Codrington'
# 'Appending Codrington to "city_data"'
# 'Evaluating city number: 6145890, Shelburne'
# 'Appending Shelburne to "city_data"'
# 'Evaluating city number: 1563241, Thanh Pho Uong Bi'
# 'Appending Thanh Pho Uong Bi to "city_data"'
# 'Evaluating city number: 1489656, Teya'
# 'Appending Teya to "city_data"'
# 'Evaluating city number: 3663517, Manaus'
# 'Appending Manaus to "city_data"'
# "Evaluating city number: 2121385, Severo-Kuril'sk"
# 'Appending Severo-Kuril\'sk to "city_data"'
# 'Evaluating city number: 5983607, Inuvik'
# 'Appending Inuvik to "city_data"'
# 'Evaluating city number: 1490054, Tashara'
# 'Appending Tashara to "city_data"'
# 'Evaluating city number: 3860443, Comodoro Rivadavia'
# 'Appending Comodoro Rivadavia to "city_data"'
# 'Evaluating city number: 1082243, Ambilobe'
# 'Appending Ambilobe to "city_data"'
# 'Evaluating city number: 1816705, Beihai'
# 'Appending Beihai to "city_data"'
# 'Evaluating city number: 2017155, Saskylakh'
# 'Appending Saskylakh to "city_data"'
# 'Evaluating city number: 118191, Rūdsar'
# 'Appending Rūdsar to "city_data"'
# 'Evaluating city number: 5134295, Rome'
# 'Appending Rome to "city_data"'
# 'Evaluating city number: 107304, Buraidah'
# 'Appending Buraidah to "city_data"'
# 'Evaluating city number: 1056899, Sambava'
# 'Appending Sambava to "city_data"'
# 'Evaluating city number: 5905393, Bonavista'
# 'Appending Bonavista to "city_data"'
# 'Evaluating city number: 5600685, Meridian'
# 'Appending Meridian to "city_data"'
# "Evaluating city number: 2013986, Ust'-Barguzin"
# 'Appending Ust\'-Barguzin to "city_data"'
# 'Evaluating city number: 2258378, Loandjili'
# 'Appending Loandjili to "city_data"'
# 'Evaluating city number: 1631637, Pemangkat'
# 'Appending Pemangkat to "city_data"'
# 'Evaluating city number: 6063191, Mackenzie'
# 'Appending Mackenzie to "city_data"'
# 'Evaluating city number: 1215502, Banda Aceh'
# 'Appending Banda Aceh to "city_data"'
# 'Evaluating city number: 2094027, Kieta'
# 'Appending Kieta to "city_data"'
# 'Evaluating city number: 2276492, Harper'
# 'Appending Harper to "city_data"'
# 'Evaluating city number: 133595, Gerāsh'
# 'Appending Gerāsh to "city_data"'
# 'Evaluating city number: 86049, Jalu'
# 'Appending Jalu to "city_data"'
# 'Evaluating city number: 1808392, Hengshui'
# 'Appending Hengshui to "city_data"'
# 'Evaluating city number: 1736458, Kudat'
# 'Appending Kudat to "city_data"'
# 'Evaluating city number: 3453315, Poconé'
# 'Appending Poconé to "city_data"'
# 'Evaluating city number: 2172880, Byron Bay'
# 'Appending Byron Bay to "city_data"'
# 'Evaluating city number: 2165828, Gatton'
# 'Appending Gatton to "city_data"'
# 'Evaluating city number: 1489853, Tazovsky'
# 'Appending Tazovsky to "city_data"'
# 'Evaluating city number: 8079926, Labuhan'
# 'Appending Labuhan to "city_data"'
# 'Evaluating city number: 4946620, Palmer'
# 'Appending Palmer to "city_data"'
# 'Evaluating city number: 1326105, Falam'
# 'Appending Falam to "city_data"'
# 'Evaluating city number: 3521108, Progreso'
# 'Appending Progreso to "city_data"'
# 'Evaluating city number: 3944399, Chancay'
# 'Appending Chancay to "city_data"'
# 'Evaluating city number: 2514301, Mahon'
# 'Appending Mahon to "city_data"'
# 'Evaluating city number: 2017658, Preobrazheniye'
# 'Appending Preobrazheniye to "city_data"'
# 'Evaluating city number: 100926, Umluj'
# 'Appending Umluj to "city_data"'
# 'Evaluating city number: 705104, Rozkishne'
# 'Appending Rozkishne to "city_data"'
# 'Evaluating city number: 2629833, Husavik'
# 'Appending Husavik to "city_data"'
# 'Evaluating city number: 2090990, Mendi'
# 'Appending Mendi to "city_data"'
# 'Evaluating city number: 240210, Birao'
# 'Appending Birao to "city_data"'
# 'Evaluating city number: 487928, Novikovo'
# 'Appending Novikovo to "city_data"'
# 'Evaluating city number: 3832791, Villa Carlos Paz'
# 'Appending Villa Carlos Paz to "city_data"'
# 'Evaluating city number: 3894426, Coyhaique'
# 'Appending Coyhaique to "city_data"'
# 'Evaluating city number: 5972291, Havre-St-Pierre'
# 'Appending Havre-St-Pierre to "city_data"'
# 'Evaluating city number: 1651103, Atambua'
# 'Appending Atambua to "city_data"'
# 'Evaluating city number: 4670234, Alice'
# 'Appending Alice to "city_data"'
# 'Evaluating city number: 295277, Eilat'
# 'Appending Eilat to "city_data"'
# 'Evaluating city number: 1714733, Dingle'
# 'Appending Dingle to "city_data"'
# 'Evaluating city number: 3939761, Hualmay'
# 'Appending Hualmay to "city_data"'
# 'Evaluating city number: 1797117, Rongcheng'
# 'Appending Rongcheng to "city_data"'
# 'Evaluating city number: 2134814, Sola'
# 'Appending Sola to "city_data"'
# 'Evaluating city number: 2212775, Sabha'
# 'Appending Sabha to "city_data"'
# 'Evaluating city number: 172515, Abu Samrah'
# 'Appending Abu Samrah to "city_data"'
# 'Evaluating city number: 2643044, Margate'
# 'Appending Margate to "city_data"'
# 'Evaluating city number: 3522526, Nuevo Progreso'
# 'Appending Nuevo Progreso to "city_data"'
# 'Evaluating city number: 2335713, Kafanchan'
# 'Appending Kafanchan to "city_data"'
# 'Evaluating city number: 1226260, Trincomalee'
# 'Appending Trincomalee to "city_data"'
# 'Evaluating city number: 6067747, Matagami'
# 'Appending Matagami to "city_data"'
# 'Evaluating city number: 3904906, Santa Cruz de la Sierra'
# 'Appending Santa Cruz de la Sierra to "city_data"'
# 'Evaluating city number: 2172797, Cairns'
# 'Appending Cairns to "city_data"'
# 'Evaluating city number: 1519924, Kushmurun'
# 'Appending Kushmurun to "city_data"'
# 'Evaluating city number: 4764534, Hollins'
# 'Appending Hollins to "city_data"'
# 'Evaluating city number: 338345, Edd'
# 'Appending Edd to "city_data"'
# 'Evaluating city number: 2013279, Vostok'
# 'Appending Vostok to "city_data"'
# 'Evaluating city number: 3457741, Marialva'
# 'Appending Marialva to "city_data"'
# 'Evaluating city number: 3361934, Saldanha'
# 'Appending Saldanha to "city_data"'
# 'Evaluating city number: 2057087, Kupang'
# 'Appending Kupang to "city_data"'
# 'Evaluating city number: 3455750, Otacílio Costa'
# 'Appending Otacílio Costa to "city_data"'
# 'Evaluating city number: 1274989, Candolim'
# 'Appending Candolim to "city_data"'
# 'Evaluating city number: 2121025, Srednekolymsk'
# 'Appending Srednekolymsk to "city_data"'
# 'Evaluating city number: 1083724, Ambanja'
# 'Appending Ambanja to "city_data"'
# 'Evaluating city number: 525426, Sobolevo'
# 'Appending Sobolevo to "city_data"'
# 'Evaluating city number: 934479, Grand Gaube'
# 'Appending Grand Gaube to "city_data"'
# 'Evaluating city number: 3117533, Manresa'
# 'Appending Manresa to "city_data"'
# 'Evaluating city number: 3657661, Gualaquiza'
# 'Appending Gualaquiza to "city_data"'
# 'Evaluating city number: 1708743, Kinablangan'
# 'Appending Kinablangan to "city_data"'
# 'Evaluating city number: 3175096, Laas'
# 'Appending Laas to "city_data"'
# 'Evaluating city number: 3372783, Ponta Delgada'
# 'Appending Ponta Delgada to "city_data"'
# 'Evaluating city number: 6100086, Peachland'
# 'Appending Peachland to "city_data"'
# 'Evaluating city number: 303750, Tall Kayf'
# 'Appending Tall Kayf to "city_data"'
# 'Evaluating city number: 1735634, Kuching'
# 'Appending Kuching to "city_data"'
# 'Evaluating city number: 2120048, Ust-Nera'
# 'Appending Ust-Nera to "city_data"'
# 'Evaluating city number: 3178019, Correggio'
# 'Appending Correggio to "city_data"'
# 'Evaluating city number: 1637001, Biak'
# 'Appending Biak to "city_data"'
# 'Evaluating city number: 2455216, Kita'
# 'Appending Kita to "city_data"'
# 'Evaluating city number: 2400547, Gamba'
# 'Appending Gamba to "city_data"'
# 'Evaluating city number: 2139521, Noumea'
# 'Appending Noumea to "city_data"'
# 'Evaluating city number: 2511174, Santa Cruz de Tenerife'
# 'Appending Santa Cruz de Tenerife to "city_data"'
# 'Evaluating city number: 3120211, Jaca'
# 'Appending Jaca to "city_data"'
# 'Evaluating city number: 3421765, Nanortalik'
# 'Appending Nanortalik to "city_data"'
# 'Evaluating city number: 3136690, Stokmarknes'
# 'Appending Stokmarknes to "city_data"'
# 'Evaluating city number: 264481, Asopós'
# 'Appending Asopós to "city_data"'
# 'Evaluating city number: 1501402, Kunashak'
# 'Appending Kunashak to "city_data"'
# 'Evaluating city number: 3160100, Beian'
# 'Appending Beian to "city_data"'
# 'Evaluating city number: 2980080, Saint-François'
# 'Appending Saint-François to "city_data"'
# 'Evaluating city number: 921906, Domoni'
# 'Appending Domoni to "city_data"'
# 'Evaluating city number: 866062, Iskateley'
# 'Appending Iskateley to "city_data"'
# 'Evaluating city number: 2426370, Umm Hājar'
# 'Appending Umm Hājar to "city_data"'
# 'Evaluating city number: 1062663, Mahajanga'
# 'Appending Mahajanga to "city_data"'
# 'Evaluating city number: 1855540, Naze'
# 'Appending Naze to "city_data"'
# 'Evaluating city number: 5364916, Lamont'
# 'Appending Lamont to "city_data"'
# 'Evaluating city number: 6096551, Pangnirtung'
# 'Appending Pangnirtung to "city_data"'
# 'Evaluating city number: 778707, Mehamn'
# 'Appending Mehamn to "city_data"'
# 'Evaluating city number: 3199862, Gostovići'
# 'Appending Gostovići to "city_data"'
# 'Evaluating city number: 3839307, Rawson'
# 'Appending Rawson to "city_data"'
# 'Evaluating city number: 88533, Awjilah'
# 'Appending Awjilah to "city_data"'
# 'Evaluating city number: 2377457, Nouadhibou'
# 'Appending Nouadhibou to "city_data"'
# 'Evaluating city number: 3460901, Itaguaçu'
# 'Appending Itaguaçu to "city_data"'
# 'Evaluating city number: 1270036, Hirekerūr'
# 'Appending Hirekerūr to "city_data"'
# 'Evaluating city number: 1513491, Yangi Marg`ilon'
# 'Appending Yangi Marg`ilon to "city_data"'
# 'Evaluating city number: 3838859, Río Gallegos'
# 'Appending Río Gallegos to "city_data"'
# 'Evaluating city number: 2159220, Mackay'
# 'Appending Mackay to "city_data"'
# 'Evaluating city number: 734315, Siátista'
# 'Appending Siátista to "city_data"'
# 'Evaluating city number: 2027316, Ayan'
# 'Appending Ayan to "city_data"'
# 'Evaluating city number: 1626542, Sorong'
# 'Appending Sorong to "city_data"'
# 'Evaluating city number: 2293801, Yendi'
# 'Appending Yendi to "city_data"'
# 'Evaluating city number: 2012530, Zhigansk'
# 'Appending Zhigansk to "city_data"'
# 'Evaluating city number: 6111867, Port Hawkesbury'
# 'Appending Port Hawkesbury to "city_data"'
# 'Evaluating city number: 964712, Plettenberg Bay'
# 'Appending Plettenberg Bay to "city_data"'
# 'Evaluating city number: 686090, Asău'
# 'Appending Asău to "city_data"'
# 'Evaluating city number: 2409914, Bonthe'
# 'Appending Bonthe to "city_data"'
# 'Evaluating city number: 287832, Ibrā’'
# 'Appending Ibrā’ to "city_data"'
# 'Evaluating city number: 3532996, Altamirano'
# 'Appending Altamirano to "city_data"'
# 'Evaluating city number: 1253150, Vinukonda'
# 'Appending Vinukonda to "city_data"'
# 'Evaluating city number: 3359638, Walvis Bay'
# 'Appending Walvis Bay to "city_data"'
# 'Evaluating city number: 2036933, Helong'
# 'Appending Helong to "city_data"'
# 'Evaluating city number: 506763, Polyarny'
# 'Appending Polyarny to "city_data"'
# 'Evaluating city number: 145531, Saurimo'
# 'Appending Saurimo to "city_data"'
# 'Evaluating city number: 1282898, Pokhara'
# 'Appending Pokhara to "city_data"'
# 'Evaluating city number: 2144528, Warrnambool'
# 'Appending Warrnambool to "city_data"'
# 'Evaluating city number: 1627035, Simpang'
# 'Appending Simpang to "city_data"'
# 'Evaluating city number: 5417737, Commerce City'
# 'Appending Commerce City to "city_data"'
# 'Evaluating city number: 3398014, Irituia'
# 'Appending Irituia to "city_data"'
# 'Evaluating city number: 3467263, Capinópolis'
# 'Appending Capinópolis to "city_data"'
# 'Evaluating city number: 1788852, Xining'
# 'Appending Xining to "city_data"'
# "Evaluating city number: 515879, Oktyabr'skiy"
# 'Appending Oktyabr\'skiy to "city_data"'
# 'Evaluating city number: 3470709, Barra do Garças'
# 'Appending Barra do Garças to "city_data"'
# 'Evaluating city number: 1529376, Korla'
# 'Appending Korla to "city_data"'
# 'Evaluating city number: 3347019, Mossamedes'
# 'Appending Mossamedes to "city_data"'
# 'Evaluating city number: 2142316, Yeppoon'
# 'Appending Yeppoon to "city_data"'
# 'Evaluating city number: 3489440, Morant Bay'
# 'Appending Morant Bay to "city_data"'
# 'Evaluating city number: 2184707, Wanaka'
# 'Appending Wanaka to "city_data"'
# 'Evaluating city number: 5026478, Fillmore'
# 'Appending Fillmore to "city_data"'
# 'Evaluating city number: 1521762, Kurchum'
# 'Appending Kurchum to "city_data"'
# 'Evaluating city number: 5417598, Colorado Springs'
# 'Appending Colorado Springs to "city_data"'
# 'Evaluating city number: 2077895, Alice Springs'
# 'Appending Alice Springs to "city_data"'
# 'Evaluating city number: 535839, Leshukonskoye'
# 'Appending Leshukonskoye to "city_data"'
# 'Evaluating city number: 3437443, Pozo Colorado'
# 'Appending Pozo Colorado to "city_data"'
# 'Evaluating city number: 6316343, Alta Floresta'
# 'Appending Alta Floresta to "city_data"'
# 'Evaluating city number: 1633442, Paciran'
# 'Appending Paciran to "city_data"'
# 'Evaluating city number: 4440975, Picayune'
# 'Appending Picayune to "city_data"'
# 'Evaluating city number: 3465769, Conceição da Barra'
# 'Appending Conceição da Barra to "city_data"'
# 'Evaluating city number: 779261, Kjøllefjord'
# 'Appending Kjøllefjord to "city_data"'
# 'Evaluating city number: 3516148, Tecolutla'
# 'Appending Tecolutla to "city_data"'
# 'Evaluating city number: 3843123, Neuquén'
# 'Appending Neuquén to "city_data"'
# 'Evaluating city number: 187896, Mandera'
# 'Appending Mandera to "city_data"'
# 'Evaluating city number: 1259395, Porbandar'
# 'Appending Porbandar to "city_data"'
# 'Evaluating city number: 1267390, Kavaratti'
# 'Appending Kavaratti to "city_data"'
# 'Evaluating city number: 6113406, Prince Rupert'
# 'Appending Prince Rupert to "city_data"'
# 'Evaluating city number: 4047434, Russell'
# 'Appending Russell to "city_data"'
# 'Evaluating city number: 2016680, Shirokiy'
# 'Appending Shirokiy to "city_data"'
# 'Evaluating city number: 935221, Saint-Paul'
# 'Appending Saint-Paul to "city_data"'
# 'Evaluating city number: 1651531, Ambon City'
# 'Appending Ambon City to "city_data"'
# 'Evaluating city number: 321572, Belen'
# 'Appending Belen to "city_data"'
# 'Evaluating city number: 1524243, Georgiyevka'
# 'Appending Georgiyevka to "city_data"'
# 'Evaluating city number: 2174003, Brisbane'
# 'Appending Brisbane to "city_data"'
# 'Evaluating city number: 2167426, Emerald'
# 'Appending Emerald to "city_data"'
# 'Evaluating city number: 667727, Scărişoara'
# 'Appending Scărişoara to "city_data"'
# 'Evaluating city number: 3416888, Grindavik'
# 'Appending Grindavik to "city_data"'
# 'Evaluating city number: 1835848, Seoul'
# 'Appending Seoul to "city_data"'
# 'Evaluating city number: 1818004, Mabai'
# 'Appending Mabai to "city_data"'
# 'Evaluating city number: 4477525, Lumberton'
# 'Appending Lumberton to "city_data"'
# 'Evaluating city number: 2027296, Aykhal'
# 'Appending Aykhal to "city_data"'
# 'Evaluating city number: 2738381, Lata'
# 'Appending Lata to "city_data"'
# 'Evaluating city number: 3430443, Necochea'
# 'Appending Necochea to "city_data"'
# 'Evaluating city number: 256614, Nea Ionia'
# 'Appending Nea Ionia to "city_data"'
# 'Evaluating city number: 1174451, Keti Bandar'
# 'Appending Keti Bandar to "city_data"'
# 'Evaluating city number: 5233053, Yankton'
# 'Appending Yankton to "city_data"'
# 'Evaluating city number: 1732826, Mersing'
# 'Appending Mersing to "city_data"'
# 'Evaluating city number: 2030065, Mandalgovi'
# 'Appending Mandalgovi to "city_data"'
# 'Evaluating city number: 5894642, Bassano'
# 'Appending Bassano to "city_data"'
# 'Evaluating city number: 2173323, Bundaberg'
# 'Appending Bundaberg to "city_data"'
# 'Evaluating city number: 5983720, Iqaluit'
# 'Appending Iqaluit to "city_data"'

# %%
pprint(r_data)
# Out:
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 63.75, 'lon': -68.51},
#  'dt': 1594668061,
#  'id': 5983720,
#  'main': {'feels_like': 285.44,
#           'humidity': 37,
#           'pressure': 1014,
#           'temp': 292.15,
#           'temp_max': 292.15,
#           'temp_min': 292.15},
#  'name': 'Iqaluit',
#  'sys': {'country': 'CA',
#          'id': 797,
#          'sunrise': 1594622975,
#          'sunset': 1594693781,
#          'type': 1},
#  'timezone': -14400,
#  'visibility': 48279,
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 310, 'gust': 10.8, 'speed': 7.7}}

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# use iloc or loc to select humidity column and then specify conditions (>100) 
#create a dataframe from city_data 
df = pd.DataFrame(city_data)
# seeing if we removed any data from the dataframe
len(df)
df.describe()
# Out:
#               Lat         Lng    Max Temp  Humidity (%)  Cloudiness  \
# count  537.000000  537.000000  537.000000    537.000000  537.000000
# mean    19.106611   19.271676  294.015959     67.752328   47.525140
# std     33.859094   90.329854    8.392232     20.926758   40.361425
# min    -54.800000 -179.170000  273.150000      3.000000    0.000000
# 25%     -9.110000  -58.800000  287.540000     54.000000    1.000000
# 50%     22.080000   23.750000  295.150000     72.000000   40.000000
# 75%     46.620000  101.770000  300.150000     84.000000   90.000000
# max     78.220000  179.320000  315.370000    100.000000  100.000000
#
#        Wind Speed      CityDate
# count  537.000000  5.370000e+02
# mean     3.591806  1.594668e+09
# std      2.384390  1.600223e+02
# min      0.140000  1.594668e+09
# 25%      1.790000  1.594668e+09
# 50%      3.100000  1.594668e+09
# 75%      5.100000  1.594668e+09
# max     14.650000  1.594668e+09

# %%
#creating dataframe without cities with humidity over 100%
df_HumUnder100 = df[df.Humidity <= 100]
# checking length of new dataframe
f'There are {len(df_HumUnder100)} cities with humidity 100% or less'
# Out:
#   File "<ipython-input-16-a93f25c9cc93>", line 2
#     df_HumUnder100 = df[df.Humidity (%) <= 100]
#                                      ^
# SyntaxError: invalid syntax

# %%
#  Get the indices of cities that have humidity =< 100%.
df_HumOvr100 = df[df.humidity > 100]
f'There are {len(df_HumOvr100)} cities with 100% humidity or less'
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-ce96af545c20> in <module>
#       1 #  Get the indices of cities that have humidity =< 100%.
# ----> 2 df_HumOvr100 = df[df.humidity > 100]
#       3 f'There are {len(df_HumOvr100)} cities with 100% humidity or less'
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'humidity'

# %%
df_HumUnder100.head()
#change the headings
#should be 'City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Wind Speed', 'Country', 'Date'

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
df_clean = df_HumUnder100[["CityName",
                           "CityID",
                           "CityLon",
                           "CityLat",
                           "CityTemp",
                           "CityHumidity",
                           "CityClouds",
                           "CityWindSpeed"]].copy()

# Need to identify humidity outliers
HumQ3 = df_clean["CityHumidity"].quantile(0.75)
HumQ1 = df_clean["CityHumidity"].quantile(0.25)
IQR = HumQ3 - HumQ1
UQR = HumQ3 + (IQR * 1.5)
LQR = HumQ1 - (IQR * 1.5)

HumList = df_clean["CityHumidity"]

outlierList = []

outliers = (HumList < LQR) | (HumList > UQR)
print(outliers)

# %%
#merge with dataframe on index, outlier = false

# %%
df_clean = df_HumUnder100[["CityName",
                           "CityID",
                           "CityLon",
                           "CityLat",
                           "CityTemp",
                           "CityHumidity",
                           "CityClouds",
                           "CityWindSpeed"]].copy()

# %%
# # Extract relevant fields from the data frame
# df_clean = df_HumUnder100[["CityName",
#                            "CityID",
#                            "CityLon",
#                            "CityLat",
#                            "CityTemp",
#                            "CityHumidity",
#                            "CityClouds",
#                            "CityWindSpeed"]].copy()

# # Export the City_Data into a csv

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
